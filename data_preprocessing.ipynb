# %%
import anndata as ad

# %%
adata = ad.read_loom("Data/Loom_data/a549_tgfb1.loom")
# Out:
# /home/csb/Saloni/CPT_GRN_analysis/.venv/lib/python3.10/site-packages/anndata/utils.py:434: FutureWarning: Importing read_loom from `anndata` is deprecated. Import anndata.io.read_loom instead.
#   warnings.warn(msg, FutureWarning)
# /home/csb/Saloni/CPT_GRN_analysis/.venv/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)
# /home/csb/Saloni/CPT_GRN_analysis/.venv/lib/python3.10/site-packages/anndata/_core/aligned_df.py:68: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
print(adata)

print("Obs : ", adata.obs.shape)
print("Var : ", adata.var.shape)
# Out:
# AnnData object with n_obs × n_vars = 3567 × 33694
#     obs: 'Clusters', '_X', '_Y', 'batch', 'obs_names', 'treatment'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'var_names'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'
# Obs :  (3567, 6)
# Var :  (33694, 6)

# %%
import scanpy as sc
import scvelo as scv
import matplotlib

print(sc.__version__)
print(scv.__version__)
print(matplotlib.__version__)
# Out:
# 1.9.1
# 0.2.5
# 3.5.3

# %%
adata = scv.read_loom("Data/Loom_data/a549_tgfb1.loom")
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 3567 × 33694
#     obs: 'Clusters', '_X', '_Y', 'batch', 'obs_names', 'treatment'
#     var: 'Accession', 'Chromosome', 'End', 'Start', 'Strand', 'var_names'
#     layers: 'matrix', 'ambiguous', 'spliced', 'unspliced'

# %%
print(adata.obs['Clusters'])

# %%
import dynamo as dyn

adata = dyn.sample_data.pancreatic_endocrinogenesis()
adata
# Out:
# |-----> Downloading data to ./data/endocrinogenesis_day15.h5ad
# |-----> in progress: 99.4381%|-----> [download] completed [475.8954s]
# /home/csb/Saloni/CPT_GRN_analysis/.venv/lib/python3.10/site-packages/anndata/compat/__init__.py:329: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   warn(
# /home/csb/Saloni/CPT_GRN_analysis/.venv/lib/python3.10/site-packages/anndata/compat/__init__.py:329: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   warn(
# AnnData object with n_obs × n_vars = 3696 × 27998
#     obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score'
#     var: 'highly_variable_genes'
#     uns: 'clusters_coarse_colors', 'clusters_colors', 'day_colors', 'neighbors', 'pca'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'spliced', 'unspliced'
# ...

# %%
import anndata as ad

adata = ad.read_h5ad('data/endocrinogenesis_day15.h5ad')
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 3696 × 27998
#     obs: 'clusters_coarse', 'clusters', 'S_score', 'G2M_score'
#     var: 'highly_variable_genes'
#     uns: 'clusters_coarse_colors', 'clusters_colors', 'day_colors', 'neighbors', 'pca'
#     obsm: 'X_pca', 'X_umap'
#     layers: 'spliced', 'unspliced'
#     obsp: 'distances', 'connectivities'
# /home/csb/Saloni/CPT_GRN_analysis/.venv/lib/python3.10/site-packages/anndata/compat/__init__.py:329: FutureWarning: Moving element from .uns['neighbors']['distances'] to .obsp['distances'].
#
# This is where adjacency matrices should go now.
#   warn(
# /home/csb/Saloni/CPT_GRN_analysis/.venv/lib/python3.10/site-packages/anndata/compat/__init__.py:329: FutureWarning: Moving element from .uns['neighbors']['connectivities'] to .obsp['connectivities'].
#
# This is where adjacency matrices should go now.
#   warn(

# %%
print(adata.obs['clusters'].unique())
# Out:
# ['Pre-endocrine', 'Ductal', 'Alpha', 'Ngn3 high EP', 'Delta', 'Beta', 'Ngn3 low EP', 'Epsilon']
# Categories (8, object): ['Ductal', 'Ngn3 low EP', 'Ngn3 high EP', 'Pre-endocrine', 'Beta', 'Alpha', 'Delta', 'Epsilon']
